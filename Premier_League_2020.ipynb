# %% [markdown]
# <a href="https://colab.research.google.com/github/tritus-soi/sample_project/blob/master/Premier_League_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ DataScienceBootcamp/data_analyst/EPL.csv')

# %%
df.shape
df.dtypes
# Out:
# Rank           float64
# Team            object
# Played         float64
# Won            float64
# Drawn          float64
# Lost           float64
# For            float64
# Against        float64
# GD             float64
# Points         float64
# Unnamed: 10    float64
# Unnamed: 11    float64
# Unnamed: 12    float64
# Unnamed: 13    float64
# Unnamed: 14    float64
# dtype: object

# %%
df.head()
# Out:
#    Rank              Team  Played  ...  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0   1.0         Liverpool    12.0  ...          NaN          NaN          NaN
# 1   2.0    Leicester City    12.0  ...          NaN          NaN          NaN
# 2   3.0           Chelsea    12.0  ...          NaN          NaN          NaN
# 3   4.0   Manchester City    12.0  ...          NaN          NaN          NaN
# 4   5.0  Sheffield United    12.0  ...          NaN          NaN          NaN
#
# [5 rows x 15 columns]

# %%
df.describe()
# Out:
#            Rank  Played        Won  ...  Unnamed: 12  Unnamed: 13  Unnamed: 14
# count  20.00000    20.0  20.000000  ...          0.0          0.0          0.0
# mean   10.50000    12.0   4.400000  ...          NaN          NaN          NaN
# std     5.91608     0.0   2.458069  ...          NaN          NaN          NaN
# min     1.00000    12.0   1.000000  ...          NaN          NaN          NaN
# 25%     5.75000    12.0   3.000000  ...          NaN          NaN          NaN
# 50%    10.50000    12.0   4.000000  ...          NaN          NaN          NaN
# 75%    15.25000    12.0   4.000000  ...          NaN          NaN          NaN
# max    20.00000    12.0  11.000000  ...          NaN          NaN          NaN
#
# [8 rows x 14 columns]

# %%
df1 = df.Rank.astype('category')

# %%
df1.describe()
# Out:
# count     20.0
# unique    20.0
# top       20.0
# freq       1.0
# Name: Rank, dtype: float64

# %%
pvt = df.pivot_table(index='Team')
pvt
# Out:
#                          Against  Drawn   For    GD  ...  Played  Points  Rank   Won
# Team                                                 ...
# AFC Bournemouth             15.0    4.0  15.0   0.0  ...    12.0    16.0   9.0   4.0
# Arsenal                     17.0    5.0  16.0  -1.0  ...    12.0    17.0   6.0   4.0
# Aston Villa                 20.0    2.0  17.0  -3.0  ...    12.0    11.0  17.0   3.0
# Brighton & Hove Albion      17.0    3.0  15.0  -2.0  ...    12.0    15.0  11.0   4.0
# Burnley                     18.0    3.0  17.0  -1.0  ...    12.0    15.0  10.0   4.0
# Chelsea                     17.0    2.0  27.0  10.0  ...    12.0    26.0   3.0   8.0
# Crystal Palace              16.0    3.0  10.0  -6.0  ...    12.0    15.0  12.0   4.0
# Everton                     18.0    2.0  13.0  -5.0  ...    12.0    14.0  15.0   4.0
# Leicester City               8.0    2.0  29.0  21.0  ...    12.0    26.0   2.0   8.0
# ...

# %%
pvt_sorted = pvt.sort_values('Won', ascending=False)
pvt_sorted
# Out:
#                          Against  Drawn   For    GD  ...  Played  Points  Rank   Won
# Team                                                 ...
# Liverpool                   10.0    1.0  28.0  18.0  ...    12.0    34.0   1.0  11.0
# Manchester City             13.0    1.0  35.0  22.0  ...    12.0    25.0   4.0   8.0
# Leicester City               8.0    2.0  29.0  21.0  ...    12.0    26.0   2.0   8.0
# Chelsea                     17.0    2.0  27.0  10.0  ...    12.0    26.0   3.0   8.0
# Sheffield United             9.0    5.0  13.0   4.0  ...    12.0    17.0   5.0   4.0
# Newcastle United            18.0    3.0  11.0  -7.0  ...    12.0    15.0  13.0   4.0
# Manchester United           12.0    4.0  16.0   4.0  ...    12.0    16.0   7.0   4.0
# Arsenal                     17.0    5.0  16.0  -1.0  ...    12.0    17.0   6.0   4.0
# AFC Bournemouth             15.0    4.0  15.0   0.0  ...    12.0    16.0   9.0   4.0
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Tahoma')

pvt = df.pivot_table(index=['Team'], values=['Won'])
pvt.sort_values('Won', ascending=True)
pvt.plot.bar()
pvt
# Out:
#                           Won
# Team
# AFC Bournemouth           4.0
# Arsenal                   4.0
# Aston Villa               3.0
# Brighton & Hove Albion    4.0
# Burnley                   4.0
# Chelsea                   8.0
# Crystal Palace            4.0
# Everton                   4.0
# Leicester City            8.0
# Liverpool                11.0
# Manchester City           8.0
# Manchester United         4.0
# Newcastle United          4.0
# Norwich City              2.0
# Sheffield United          4.0
# Southamton                2.0
# Tottenham Hotspur         3.0
# Watford                   1.0
# West Ham United           3.0
# Wolverhampton Wanderers   3.0

# %%
pvt2 = df.pivot_table(index=['Team'], columns =['Points'], values=['Won'])
pvt2.plot.bar()
