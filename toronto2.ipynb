# %% [markdown]
# <a href="https://colab.research.google.com/github/tritus-soi/Coursera_Capstone/blob/master/toronto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## List of postal codes in Canada where the first letter is M.
# ### Postal codes beginning with M are located within the city of Toronto in the province of Ontario.

# %%
import pandas as pd

# %%
toronto=pd.read_csv("https://docs.google.com/spreadsheets/d/1KH1-y1wDGMIG9Zu_XnRCbstIMB36krPAzfb8SSYlHtk/gviz/tq?tqx=out:csv")
toronto.head(20)
# Out:
#    Postal Code  ...                                       Neighborhood
# 0          M3A  ...                                          Parkwoods
# 1          M4A  ...                                   Victoria Village
# 2          M5A  ...                          Regent Park, Harbourfront
# 3          M6A  ...                   Lawrence Manor, Lawrence Heights
# 4          M7A  ...        Queen's Park, Ontario Provincial Government
# 5          M9A  ...            Islington Avenue, Humber Valley Village
# 6          M1B  ...                                     Malvern, Rouge
# 7          M3B  ...                                          Don Mills
# 8          M4B  ...                    Parkview Hill, Woodbine Gardens
# 9          M5B  ...                           Garden District, Ryerson
# 10         M6B  ...                                          Glencairn
# 11         M9B  ...  West Deane Park, Princess Gardens, Martin Grov...
# ...

# %%
toronto.shape
# Out:
# (103, 3)

# %%
coordinates=pd.read_csv("https://cocl.us/Geospatial_data")
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_to=(pd.merge(toronto,coordinates,on='Postal Code'))
df_to.head(20)
# Out:
#    Postal Code           Borough  ...   Latitude  Longitude
# 0          M3A        North York  ...  43.753259 -79.329656
# 1          M4A        North York  ...  43.725882 -79.315572
# 2          M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3          M6A        North York  ...  43.718518 -79.464763
# 4          M7A  Downtown Toronto  ...  43.662301 -79.389494
# 5          M9A         Etobicoke  ...  43.667856 -79.532242
# 6          M1B       Scarborough  ...  43.806686 -79.194353
# 7          M3B        North York  ...  43.745906 -79.352188
# 8          M4B         East York  ...  43.706397 -79.309937
# 9          M5B  Downtown Toronto  ...  43.657162 -79.378937
# 10         M6B        North York  ...  43.709577 -79.445073
# 11         M9B         Etobicoke  ...  43.650943 -79.554724
# 12         M1C       Scarborough  ...  43.784535 -79.160497
# 13         M3C        North York  ...  43.725900 -79.340923
# 14         M4C         East York  ...  43.695344 -79.318389
# ...
